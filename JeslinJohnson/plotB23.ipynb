# %%
men = [22,30,35,35,26]
women= [25,32,30,35,29]

# %%
interval = [10,20,30,40,50]
interval1 = [12,22,32,42,52]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.bar(interval,men,width=3,label='men')
plt.bar(interval1,women,width=3,label='women')

plt.legend()
plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by Person')
# Out:
# Text(0.5, 1.0, 'Scores by Person')

# %%
s2 = pd.read_csv("E:\exam23\medal.csv")

s2
# Out:
#          country  gold_medal
# 0  United States          46
# 1  Great Britain          27
# 2          China          26
# 3         Russia          19
# 4        Germany          17

# %%
country = s2['country']
country
# Out:
# 0    United States
# 1    Great Britain
# 2            China
# 3           Russia
# 4          Germany
# Name: country, dtype: object

# %%
gold_medal =s2['gold_medal']
gold_medal
# Out:
# 0    46
# 1    27
# 2    26
# 3    19
# 4    17
# Name: gold_medal, dtype: int64

# %%
plt.pie(gold_medal,labels=country)
# Out:
# ([<matplotlib.patches.Wedge at 0x197d3f5c750>,
# ...
#  [Text(0.5276844259140197, 0.9651679370181085, 'United States'),
#   Text(-1.0246277154553132, 0.40017251869765635, 'Great Britain'),
#   Text(-0.7168229424450668, -0.8343649496379847, 'China'),
#   Text(0.3641697549943344, -1.037969358674603, 'Russia'),
#   Text(1.015038685557071, -0.4239062005002681, 'Germany')])
