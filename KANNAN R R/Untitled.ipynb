# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
f=pd.read_csv('data.csv')

# %%
x=f.drop(columns=['diagnosis'])
y=f['diagnosis']

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)
xtest
# Out:
#    sore_throat  fever  swollen_glands  congestion  headache
# 2            1      1               0           1         0
# 9            1      1               0           1         1

# %%
Dt=DecisionTreeClassifier()
Dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
tree.plot_tree(Dt,feature_names=['sore_throat','fever','swollen_gland','congestion','headache'],class_names=['Strep_throat','Allergy','Cold'],filled=True)
# Out:
# [Text(200.88000000000002, 181.2, 'swollen_gland <= 0.5\nentropy = 0.656\nsamples = 8\nvalue = [3, 2, 3]\nclass = Strep_throat'),
#  Text(133.92000000000002, 108.72, 'fever <= 0.5\nentropy = 0.48\nsamples = 5\nvalue = [3, 2, 0]\nclass = Strep_throat'),
#  Text(66.96000000000001, 36.23999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0]\nclass = Strep_throat'),
#  Text(200.88000000000002, 36.23999999999998, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = Allergy'),
#  Text(267.84000000000003, 108.72, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Cold')]

# %%
# p=Dt.predict()
xtest
# Out:
#    sore_throat  fever  swollen_glands  congestion  headache
# 2            1      1               0           1         0
# 9            1      1               0           1         1

# %%
new=pd.DataFrame(columns=['sore_throat','fever','swollen_glands','congestion','headache'])

# %%
new.add(v)
# Out:
# Empty DataFrame
# Columns: [sore_throat, fever, swollen_glands, congestion, headache]
# Index: []

# %%
new
# Out:
# Empty DataFrame
# Columns: [sore_throat, fever, swollen_glands, congestion, headache]
# Index: []
