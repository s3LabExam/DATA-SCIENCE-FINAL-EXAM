# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
f=pd.read_csv('data.csv')

# %%
x=f.drop(columns=['diagnosis'])
y=f['diagnosis']

# xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)
# xtest

# %%
Dt=DecisionTreeClassifier(criterion='entropy')
Dt.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
tree.plot_tree(Dt,
               feature_names=['sore_throat','fever','swollen_gland','congestion','headache'],
               class_names=['Strep_throat','Allergy','Cold'],
               filled=True)
# Out:
# [Text(200.88000000000002, 181.2, 'swollen_gland <= 0.5\nentropy = 1.571\nsamples = 10\nvalue = [3, 4, 3]\nclass = Allergy'),
#  Text(133.92000000000002, 108.72, 'fever <= 0.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4, 0]\nclass = Allergy'),
#  Text(66.96000000000001, 36.23999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0]\nclass = Strep_throat'),
#  Text(200.88000000000002, 36.23999999999998, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]\nclass = Allergy'),
#  Text(267.84000000000003, 108.72, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Cold')]

# %%
new=pd.read_csv('test.csv')
new
# Out:
#    sore_throat  fever  swollen_glands  congestion  headache
# 0            1      1               1           1         1

# %%
Dt.predict(new)
# Out:
# array(['Strep_Throat'], dtype=object)
