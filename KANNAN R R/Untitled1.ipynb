# %%
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# C:\Users\Admin\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
p=pd.read_csv('pie.csv')

# %%
l=p['country']
medal=p['gold_medal']
plt.pie(medal,labels=l)
# Out:
# ([<matplotlib.patches.Wedge at 0x246dba25b70>,
# ...
#  [Text(0.5276844259140197, 0.9651679370181085, 'United States'),
#   Text(-1.0246277154553132, 0.40017251869765635, 'Great Britain'),
#   Text(-0.7168229424450668, -0.8343649496379847, 'China'),
#   Text(0.3641697549943344, -1.037969358674603, 'Russia'),
#   Text(1.015038685557071, -0.4239062005002681, 'Germany')])

# %%
m=[22,30,35,35,26]
w=[25,32,30,35,29]
c1=[10,20,30,40,50]
c2=[12,22,32,42,52]
label=['Men','Women']

# %%
plt.figure(figsize=(10,5))
plt.bar(c1,m,label='men',color='blue',width=2)
plt.bar(c2,w,label='women',color='red',width=2)
plt.legend()
plt.xlabel('Person')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %%
plt.bar(1,12,color='blue',width=2)
plt.bar(1,34,color='red',width=1)
# Out:
# <BarContainer object of 1 artists>
